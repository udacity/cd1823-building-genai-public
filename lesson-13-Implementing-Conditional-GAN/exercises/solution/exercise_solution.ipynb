# %% [markdown]
# ## Import Required Libraries

# %%
# Make the shared `models` package (at the project root) importable from this
# lesson folder. Without this, `from models... import ...` raises ModuleNotFoundError.
import sys, pathlib
_root = next((p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
              if (p / "models").is_dir()), None)
if _root and str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Import cGAN from demo

from models.cgan import create_cgan_models
from models.cgan_training import ConditionalGANTrainer, initialize_weights

# CIFAR-10 class names
CIFAR10_CLASSES = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
]

torch.manual_seed(42)
np.random.seed(42)

# Determine device
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(f"Using device: {device}\n")
# Out:
# Using device: cuda

# %% [markdown]
# ## Solution 1: Load CIFAR-10 Dataset

# %%
#ToDo

print("=" * 80)
print("SOLUTION 1: Loading CIFAR-10 Dataset")
print("=" * 80)

transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ]
)

train_dataset = datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform
)

batch_size = 64
train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,  # MPS compatibility
)

print(f" Dataset loaded: {len(train_dataset)} training images")
print(f" DataLoader: {len(train_loader)} batches of size {batch_size}\n")
# Out:
# ================================================================================
# SOLUTION 1: Loading CIFAR-10 Dataset
# ================================================================================
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:01<00:00, 104MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
#  Dataset loaded: 50000 training images
#  DataLoader: 782 batches of size 64

# %% [markdown]
# ## Solution 2: Create cGAN Models

# %%
print("=" * 80)
print("SOLUTION 2: Creating cGAN Models")
print("=" * 80)

latent_dim = 100
num_classes = 10
label_dim = 50

#ToDo
generator, discriminator = create_cgan_models(
    latent_dim=latent_dim,
    num_classes=num_classes,
    label_dim=label_dim,
    num_channels=3,
    device=device,
)

# Initialize weights following DCGAN guidelines
initialize_weights(generator)
initialize_weights(discriminator)

print(
    f" Generator created: {sum(p.numel() for p in generator.parameters()):,} parameters"
)
print(
    f" Discriminator created: {sum(p.numel() for p in discriminator.parameters()):,} parameters\n"
)
# Out:
# ================================================================================
# SOLUTION 2: Creating cGAN Models
# ================================================================================
#  Generator created: 2,869,172 parameters
#  Discriminator created: 1,373,109 parameters

# %% [markdown]
# ## Solution 3: Create Trainer

# %%
print("=" * 80)
print("SOLUTION 3: Creating Trainer")
print("=" * 80)

#ToDo
trainer = ConditionalGANTrainer(
    generator=generator,
    discriminator=discriminator,
    device=device,
    lr_g=0.0002,
    lr_d=0.0002,
    beta1=0.5,
    beta2=0.999,
)

print(" Trainer initialized with:")
print("  - Learning rate (G): 0.0002")
print("  - Learning rate (D): 0.0002")
print("  - Beta1: 0.5, Beta2: 0.999\n")
# Out:
# ================================================================================
# SOLUTION 3: Creating Trainer
# ================================================================================
#  Trainer initialized with:
#   - Learning rate (G): 0.0002
#   - Learning rate (D): 0.0002
#   - Beta1: 0.5, Beta2: 0.999

# %% [markdown]
# ## Solution 4: Train the cGAN

# %%
print("=" * 80)
print("SOLUTION 4: Training cGAN (20 epochs)")
print("=" * 80)
print("Note: This will take 20-30 minutes on GPU\n")

#ToDo
num_epochs = 20
results = trainer.train(
    train_loader=train_loader,
    num_epochs=num_epochs,
    latent_dim=latent_dim,
    num_classes=num_classes,
    log_interval=50,
)

print(f" Training complete after {num_epochs} epochs\n")
# Out:
# ================================================================================
# SOLUTION 4: Training cGAN (20 epochs)
# ================================================================================
# Note: This will take 20-30 minutes on GPU
#
#
# ================================================================================
# Starting Conditional GAN (cGAN) Training
# ================================================================================
# Device: cuda
# Epochs: 20
# Classes: 10
# Dataset size: 50048
# ================================================================================
#
# Epoch [1/20] Batch [50/782] D_loss: 0.8515 | G_loss: 2.5374
# Epoch [1/20] Batch [100/782] D_loss: 1.2188 | G_loss: 2.9825
# Epoch [1/20] Batch [150/782] D_loss: 0.8263 | G_loss: 2.5578
# Epoch [1/20] Batch [200/782] D_loss: 1.1693 | G_loss: 2.1603
# Epoch [1/20] Batch [250/782] D_loss: 0.7190 | G_loss: 2.8311
# Epoch [1/20] Batch [300/782] D_loss: 0.9810 | G_loss: 2.0087
# Epoch [1/20] Batch [350/782] D_loss: 1.0853 | G_loss: 2.0505
# Epoch [1/20] Batch [400/782] D_loss: 0.6244 | G_loss: 1.9462
# Epoch [1/20] Batch [450/782] D_loss: 0.7904 | G_loss: 3.1469
# Epoch [1/20] Batch [500/782] D_loss: 0.8504 | G_loss: 3.3459
# Epoch [1/20] Batch [550/782] D_loss: 0.5614 | G_loss: 2.2369
# Epoch [1/20] Batch [600/782] D_loss: 0.8109 | G_loss: 1.8451
# Epoch [1/20] Batch [650/782] D_loss: 0.8142 | G_loss: 2.2711
# Epoch [1/20] Batch [700/782] D_loss: 0.8705 | G_loss: 2.0957
# Epoch [1/20] Batch [750/782] D_loss: 0.7944 | G_loss: 1.8064
#
#  Epoch 1 Complete - Avg D_loss: 0.9905 | Avg G_loss: 2.2568
#
# Epoch [2/20] Batch [50/782] D_loss: 0.8595 | G_loss: 2.1638
# Epoch [2/20] Batch [100/782] D_loss: 0.7501 | G_loss: 1.9609
# Epoch [2/20] Batch [150/782] D_loss: 0.8505 | G_loss: 2.1979
# Epoch [2/20] Batch [200/782] D_loss: 1.1171 | G_loss: 2.1429
# Epoch [2/20] Batch [250/782] D_loss: 1.0834 | G_loss: 2.1817
# Epoch [2/20] Batch [300/782] D_loss: 0.7747 | G_loss: 1.3961
# Epoch [2/20] Batch [350/782] D_loss: 0.8452 | G_loss: 1.7203
# Epoch [2/20] Batch [400/782] D_loss: 0.7485 | G_loss: 2.1114
# Epoch [2/20] Batch [450/782] D_loss: 0.7387 | G_loss: 1.9199
# Epoch [2/20] Batch [500/782] D_loss: 0.9146 | G_loss: 1.8205
# Epoch [2/20] Batch [550/782] D_loss: 1.1876 | G_loss: 1.6839
# Epoch [2/20] Batch [600/782] D_loss: 0.9464 | G_loss: 1.7215
# Epoch [2/20] Batch [650/782] D_loss: 0.9364 | G_loss: 2.2097
# Epoch [2/20] Batch [700/782] D_loss: 1.0004 | G_loss: 2.7326
# Epoch [2/20] Batch [750/782] D_loss: 0.8297 | G_loss: 2.0982
# Epoch [3/20] Batch [50/782] D_loss: 1.3978 | G_loss: 1.5345
# Epoch [3/20] Batch [100/782] D_loss: 1.1571 | G_loss: 1.7115
# Epoch [3/20] Batch [150/782] D_loss: 1.1802 | G_loss: 1.6819
# Epoch [3/20] Batch [200/782] D_loss: 1.1432 | G_loss: 1.2498
# Epoch [3/20] Batch [250/782] D_loss: 0.9706 | G_loss: 1.6229
# Epoch [3/20] Batch [300/782] D_loss: 0.9025 | G_loss: 1.2476
# Epoch [3/20] Batch [350/782] D_loss: 1.4281 | G_loss: 1.6752
# Epoch [3/20] Batch [400/782] D_loss: 1.0730 | G_loss: 1.5501
# Epoch [3/20] Batch [450/782] D_loss: 0.8381 | G_loss: 2.0568
# Epoch [3/20] Batch [500/782] D_loss: 1.0083 | G_loss: 1.8021
# Epoch [3/20] Batch [550/782] D_loss: 0.9326 | G_loss: 1.7406
# Epoch [3/20] Batch [600/782] D_loss: 1.1557 | G_loss: 1.7089
# Epoch [3/20] Batch [650/782] D_loss: 0.6255 | G_loss: 2.1097
# Epoch [3/20] Batch [700/782] D_loss: 0.6486 | G_loss: 2.1072
# Epoch [3/20] Batch [750/782] D_loss: 0.8371 | G_loss: 1.4836
# Epoch [4/20] Batch [50/782] D_loss: 1.1488 | G_loss: 1.5470
# Epoch [4/20] Batch [100/782] D_loss: 0.9125 | G_loss: 1.3433
# Epoch [4/20] Batch [150/782] D_loss: 1.3496 | G_loss: 1.3039
# Epoch [4/20] Batch [200/782] D_loss: 1.1948 | G_loss: 1.4818
# Epoch [4/20] Batch [250/782] D_loss: 1.0252 | G_loss: 1.3140
# Epoch [4/20] Batch [300/782] D_loss: 1.1714 | G_loss: 1.5783
# Epoch [4/20] Batch [350/782] D_loss: 0.9423 | G_loss: 1.3907
# Epoch [4/20] Batch [400/782] D_loss: 0.8978 | G_loss: 1.3663
# Epoch [4/20] Batch [450/782] D_loss: 1.0618 | G_loss: 1.3734
# Epoch [4/20] Batch [500/782] D_loss: 1.2649 | G_loss: 2.1179
# Epoch [4/20] Batch [550/782] D_loss: 1.1836 | G_loss: 1.4046
# Epoch [4/20] Batch [600/782] D_loss: 0.8879 | G_loss: 1.8796
# Epoch [4/20] Batch [650/782] D_loss: 0.7519 | G_loss: 1.7476
# Epoch [4/20] Batch [700/782] D_loss: 1.0626 | G_loss: 1.3192
# Epoch [4/20] Batch [750/782] D_loss: 1.0012 | G_loss: 1.6326
# Epoch [5/20] Batch [50/782] D_loss: 1.1021 | G_loss: 1.6741
# Epoch [5/20] Batch [100/782] D_loss: 1.0875 | G_loss: 1.7718
# Epoch [5/20] Batch [150/782] D_loss: 1.0604 | G_loss: 2.1088
# Epoch [5/20] Batch [200/782] D_loss: 1.1032 | G_loss: 1.6619
# Epoch [5/20] Batch [250/782] D_loss: 1.1768 | G_loss: 1.6192
# Epoch [5/20] Batch [300/782] D_loss: 1.2994 | G_loss: 2.0487
# Epoch [5/20] Batch [350/782] D_loss: 1.0203 | G_loss: 1.4593
# Epoch [5/20] Batch [400/782] D_loss: 1.0359 | G_loss: 1.4247
# Epoch [5/20] Batch [450/782] D_loss: 1.1782 | G_loss: 1.3384
# Epoch [5/20] Batch [500/782] D_loss: 1.1931 | G_loss: 1.2755
# Epoch [5/20] Batch [550/782] D_loss: 1.1405 | G_loss: 1.4120
# Epoch [5/20] Batch [600/782] D_loss: 0.9123 | G_loss: 2.2092
# Epoch [5/20] Batch [650/782] D_loss: 1.0880 | G_loss: 1.4422
# Epoch [5/20] Batch [700/782] D_loss: 0.9580 | G_loss: 1.1517
# Epoch [5/20] Batch [750/782] D_loss: 1.6674 | G_loss: 1.8260
# Epoch [6/20] Batch [50/782] D_loss: 1.0611 | G_loss: 1.6995
# Epoch [6/20] Batch [100/782] D_loss: 0.8287 | G_loss: 1.9008
# Epoch [6/20] Batch [150/782] D_loss: 1.1293 | G_loss: 2.1028
# Epoch [6/20] Batch [200/782] D_loss: 1.2078 | G_loss: 1.5653
# Epoch [6/20] Batch [250/782] D_loss: 1.0880 | G_loss: 1.6570
# Epoch [6/20] Batch [300/782] D_loss: 0.9516 | G_loss: 1.4584
# Epoch [6/20] Batch [350/782] D_loss: 1.0095 | G_loss: 1.4775
# Epoch [6/20] Batch [400/782] D_loss: 1.1388 | G_loss: 1.5332
# Epoch [6/20] Batch [450/782] D_loss: 1.0091 | G_loss: 1.8516
# Epoch [6/20] Batch [500/782] D_loss: 1.1686 | G_loss: 2.1523
# Epoch [6/20] Batch [550/782] D_loss: 0.9677 | G_loss: 1.7051
# Epoch [6/20] Batch [600/782] D_loss: 1.0059 | G_loss: 1.7265
# Epoch [6/20] Batch [650/782] D_loss: 0.9900 | G_loss: 2.0803
# Epoch [6/20] Batch [700/782] D_loss: 1.0082 | G_loss: 1.6913
# Epoch [6/20] Batch [750/782] D_loss: 1.3607 | G_loss: 1.3992
# Epoch [7/20] Batch [50/782] D_loss: 1.1557 | G_loss: 1.8323
# Epoch [7/20] Batch [100/782] D_loss: 0.8494 | G_loss: 1.8269
# Epoch [7/20] Batch [150/782] D_loss: 1.0950 | G_loss: 1.6646
# Epoch [7/20] Batch [200/782] D_loss: 1.1016 | G_loss: 1.2462
# Epoch [7/20] Batch [250/782] D_loss: 0.9877 | G_loss: 1.9000
# Epoch [7/20] Batch [300/782] D_loss: 0.9400 | G_loss: 1.6462
# Epoch [7/20] Batch [350/782] D_loss: 1.1698 | G_loss: 1.4779
# Epoch [7/20] Batch [400/782] D_loss: 0.8893 | G_loss: 1.6882
# Epoch [7/20] Batch [450/782] D_loss: 0.6534 | G_loss: 2.0563
# Epoch [7/20] Batch [500/782] D_loss: 1.2492 | G_loss: 2.8086
# Epoch [7/20] Batch [550/782] D_loss: 1.3303 | G_loss: 1.8944
# Epoch [7/20] Batch [600/782] D_loss: 0.7417 | G_loss: 2.0680
# Epoch [7/20] Batch [650/782] D_loss: 0.6927 | G_loss: 1.9333
# Epoch [7/20] Batch [700/782] D_loss: 0.7845 | G_loss: 2.1829
# Epoch [7/20] Batch [750/782] D_loss: 0.9265 | G_loss: 2.1228
# Epoch [8/20] Batch [50/782] D_loss: 0.9509 | G_loss: 1.8790
# Epoch [8/20] Batch [100/782] D_loss: 1.0726 | G_loss: 2.2726
# Epoch [8/20] Batch [150/782] D_loss: 0.9153 | G_loss: 2.0045
# Epoch [8/20] Batch [200/782] D_loss: 1.1612 | G_loss: 2.1844
# Epoch [8/20] Batch [250/782] D_loss: 0.9882 | G_loss: 1.3369
# Epoch [8/20] Batch [300/782] D_loss: 0.9103 | G_loss: 1.7636
# Epoch [8/20] Batch [350/782] D_loss: 0.9725 | G_loss: 1.7037
# Epoch [8/20] Batch [400/782] D_loss: 1.3421 | G_loss: 1.8267
# Epoch [8/20] Batch [450/782] D_loss: 0.8357 | G_loss: 2.0935
# Epoch [8/20] Batch [500/782] D_loss: 1.2544 | G_loss: 1.8367
# Epoch [8/20] Batch [550/782] D_loss: 0.6481 | G_loss: 1.6777
# Epoch [8/20] Batch [600/782] D_loss: 0.6590 | G_loss: 1.7119
# Epoch [8/20] Batch [650/782] D_loss: 0.9994 | G_loss: 1.4294
# Epoch [8/20] Batch [700/782] D_loss: 0.8295 | G_loss: 1.7544
# Epoch [8/20] Batch [750/782] D_loss: 0.8849 | G_loss: 1.6810
# Epoch [9/20] Batch [50/782] D_loss: 0.9388 | G_loss: 2.6201
# Epoch [9/20] Batch [100/782] D_loss: 1.0577 | G_loss: 2.1597
# Epoch [9/20] Batch [150/782] D_loss: 0.9257 | G_loss: 2.1303
# Epoch [9/20] Batch [200/782] D_loss: 1.0285 | G_loss: 2.4067
# Epoch [9/20] Batch [250/782] D_loss: 0.9045 | G_loss: 1.4306
# Epoch [9/20] Batch [300/782] D_loss: 1.0650 | G_loss: 2.1081
# Epoch [9/20] Batch [350/782] D_loss: 1.0224 | G_loss: 1.9524
# Epoch [9/20] Batch [400/782] D_loss: 0.7879 | G_loss: 2.0926
# Epoch [9/20] Batch [450/782] D_loss: 0.9286 | G_loss: 2.4251
# Epoch [9/20] Batch [500/782] D_loss: 0.9620 | G_loss: 2.3816
# Epoch [9/20] Batch [550/782] D_loss: 0.6856 | G_loss: 1.6857
# Epoch [9/20] Batch [600/782] D_loss: 1.1241 | G_loss: 1.6098
# Epoch [9/20] Batch [650/782] D_loss: 0.8198 | G_loss: 1.5537
# Epoch [9/20] Batch [700/782] D_loss: 1.3575 | G_loss: 2.4089
# Epoch [9/20] Batch [750/782] D_loss: 1.2659 | G_loss: 2.8895
# Epoch [10/20] Batch [50/782] D_loss: 0.5339 | G_loss: 1.7081
# Epoch [10/20] Batch [100/782] D_loss: 1.0377 | G_loss: 2.0991
# Epoch [10/20] Batch [150/782] D_loss: 0.7811 | G_loss: 1.8156
# Epoch [10/20] Batch [200/782] D_loss: 0.7492 | G_loss: 1.6233
# Epoch [10/20] Batch [250/782] D_loss: 1.0231 | G_loss: 1.8439
# Epoch [10/20] Batch [300/782] D_loss: 0.8980 | G_loss: 1.5839
# Epoch [10/20] Batch [350/782] D_loss: 0.7252 | G_loss: 1.8388
# Epoch [10/20] Batch [400/782] D_loss: 0.9240 | G_loss: 2.3737
# Epoch [10/20] Batch [450/782] D_loss: 0.7999 | G_loss: 1.4646
# Epoch [10/20] Batch [500/782] D_loss: 0.8565 | G_loss: 2.0908
# Epoch [10/20] Batch [550/782] D_loss: 0.8227 | G_loss: 1.4839
# Epoch [10/20] Batch [600/782] D_loss: 0.9511 | G_loss: 2.4111
# Epoch [10/20] Batch [650/782] D_loss: 0.8307 | G_loss: 2.2878
# Epoch [10/20] Batch [700/782] D_loss: 0.8539 | G_loss: 2.2665
# Epoch [10/20] Batch [750/782] D_loss: 0.5291 | G_loss: 1.8692
#
#  Epoch 10 Complete - Avg D_loss: 0.9075 | Avg G_loss: 1.9905
#
# Epoch [11/20] Batch [50/782] D_loss: 0.9641 | G_loss: 1.8594
# Epoch [11/20] Batch [100/782] D_loss: 0.8788 | G_loss: 1.5172
# Epoch [11/20] Batch [150/782] D_loss: 0.6941 | G_loss: 1.7958
# Epoch [11/20] Batch [200/782] D_loss: 0.8324 | G_loss: 2.1358
# Epoch [11/20] Batch [250/782] D_loss: 0.6705 | G_loss: 1.8245
# Epoch [11/20] Batch [300/782] D_loss: 0.6501 | G_loss: 2.0271
# Epoch [11/20] Batch [350/782] D_loss: 0.8226 | G_loss: 1.5290
# Epoch [11/20] Batch [400/782] D_loss: 0.6222 | G_loss: 2.5765
# Epoch [11/20] Batch [450/782] D_loss: 1.0401 | G_loss: 2.1134
# Epoch [11/20] Batch [500/782] D_loss: 0.7341 | G_loss: 1.7854
# Epoch [11/20] Batch [550/782] D_loss: 0.6643 | G_loss: 2.0895
# Epoch [11/20] Batch [600/782] D_loss: 1.0039 | G_loss: 1.5699
# Epoch [11/20] Batch [650/782] D_loss: 0.9493 | G_loss: 2.3395
# Epoch [11/20] Batch [700/782] D_loss: 0.7179 | G_loss: 2.0563
# Epoch [11/20] Batch [750/782] D_loss: 0.7921 | G_loss: 1.6322
# Epoch [12/20] Batch [50/782] D_loss: 0.8903 | G_loss: 3.1327
# Epoch [12/20] Batch [100/782] D_loss: 1.1055 | G_loss: 4.0989
# Epoch [12/20] Batch [150/782] D_loss: 0.7132 | G_loss: 2.3353
# Epoch [12/20] Batch [200/782] D_loss: 0.8829 | G_loss: 1.6318
# Epoch [12/20] Batch [250/782] D_loss: 0.7610 | G_loss: 2.8346
# Epoch [12/20] Batch [300/782] D_loss: 0.8036 | G_loss: 2.3201
# Epoch [12/20] Batch [350/782] D_loss: 0.7583 | G_loss: 1.7573
# Epoch [12/20] Batch [400/782] D_loss: 0.7710 | G_loss: 1.9792
# Epoch [12/20] Batch [450/782] D_loss: 0.8367 | G_loss: 2.2829
# Epoch [12/20] Batch [500/782] D_loss: 0.7665 | G_loss: 2.6162
# Epoch [12/20] Batch [550/782] D_loss: 0.8349 | G_loss: 2.8737
# Epoch [12/20] Batch [600/782] D_loss: 0.8611 | G_loss: 2.4940
# Epoch [12/20] Batch [650/782] D_loss: 0.9055 | G_loss: 1.8224
# Epoch [12/20] Batch [700/782] D_loss: 0.7848 | G_loss: 2.4981
# Epoch [12/20] Batch [750/782] D_loss: 0.7132 | G_loss: 1.7143
# Epoch [13/20] Batch [50/782] D_loss: 0.6165 | G_loss: 2.3001
# Epoch [13/20] Batch [100/782] D_loss: 0.9001 | G_loss: 1.9241
# Epoch [13/20] Batch [150/782] D_loss: 0.4966 | G_loss: 2.2072
# Epoch [13/20] Batch [200/782] D_loss: 0.5785 | G_loss: 2.1976
# Epoch [13/20] Batch [250/782] D_loss: 0.7216 | G_loss: 2.1846
# Epoch [13/20] Batch [300/782] D_loss: 0.6602 | G_loss: 1.7002
# Epoch [13/20] Batch [350/782] D_loss: 0.9712 | G_loss: 2.1973
# Epoch [13/20] Batch [400/782] D_loss: 0.7789 | G_loss: 3.0010
# Epoch [13/20] Batch [450/782] D_loss: 1.6519 | G_loss: 3.4933
# Epoch [13/20] Batch [500/782] D_loss: 0.7898 | G_loss: 1.6947
# Epoch [13/20] Batch [550/782] D_loss: 1.4618 | G_loss: 1.8018
# Epoch [13/20] Batch [600/782] D_loss: 0.6107 | G_loss: 2.3878
# Epoch [13/20] Batch [650/782] D_loss: 0.8315 | G_loss: 3.0759
# Epoch [13/20] Batch [700/782] D_loss: 0.8778 | G_loss: 2.6954
# Epoch [13/20] Batch [750/782] D_loss: 0.6763 | G_loss: 3.0763
# Epoch [14/20] Batch [50/782] D_loss: 0.9321 | G_loss: 2.3194
# Epoch [14/20] Batch [100/782] D_loss: 1.4068 | G_loss: 2.0642
# Epoch [14/20] Batch [150/782] D_loss: 0.8170 | G_loss: 2.5855
# Epoch [14/20] Batch [200/782] D_loss: 0.9824 | G_loss: 2.1705
# Epoch [14/20] Batch [250/782] D_loss: 0.6239 | G_loss: 2.3734
# Epoch [14/20] Batch [300/782] D_loss: 0.7513 | G_loss: 3.2099
# Epoch [14/20] Batch [350/782] D_loss: 0.8918 | G_loss: 1.5948
# Epoch [14/20] Batch [400/782] D_loss: 0.7834 | G_loss: 1.7840
# Epoch [14/20] Batch [450/782] D_loss: 0.6582 | G_loss: 2.7121
# Epoch [14/20] Batch [500/782] D_loss: 0.8520 | G_loss: 2.6227
# Epoch [14/20] Batch [550/782] D_loss: 0.6405 | G_loss: 2.3609
# Epoch [14/20] Batch [600/782] D_loss: 0.9528 | G_loss: 1.9426
# Epoch [14/20] Batch [650/782] D_loss: 0.3813 | G_loss: 2.4418
# Epoch [14/20] Batch [700/782] D_loss: 0.8299 | G_loss: 2.6488
# Epoch [14/20] Batch [750/782] D_loss: 0.7504 | G_loss: 1.7834
# Epoch [15/20] Batch [50/782] D_loss: 0.8132 | G_loss: 1.6806
# Epoch [15/20] Batch [100/782] D_loss: 0.5102 | G_loss: 2.3959
# Epoch [15/20] Batch [150/782] D_loss: 0.5277 | G_loss: 1.9340
# Epoch [15/20] Batch [200/782] D_loss: 0.7081 | G_loss: 2.0774
# Epoch [15/20] Batch [250/782] D_loss: 0.7317 | G_loss: 2.2000
# Epoch [15/20] Batch [300/782] D_loss: 0.7620 | G_loss: 1.9914
# Epoch [15/20] Batch [350/782] D_loss: 0.7228 | G_loss: 2.2644
# Epoch [15/20] Batch [400/782] D_loss: 0.9526 | G_loss: 1.6202
# Epoch [15/20] Batch [450/782] D_loss: 0.9621 | G_loss: 2.1519
# Epoch [15/20] Batch [500/782] D_loss: 0.6539 | G_loss: 2.1133
# Epoch [15/20] Batch [550/782] D_loss: 0.6233 | G_loss: 3.3295
# Epoch [15/20] Batch [600/782] D_loss: 0.6693 | G_loss: 3.0549
# Epoch [15/20] Batch [650/782] D_loss: 0.4070 | G_loss: 2.1371
# Epoch [15/20] Batch [700/782] D_loss: 0.7572 | G_loss: 3.0736
# Epoch [15/20] Batch [750/782] D_loss: 0.5494 | G_loss: 2.6074
# Epoch [16/20] Batch [50/782] D_loss: 0.6806 | G_loss: 2.8025
# Epoch [16/20] Batch [100/782] D_loss: 0.6171 | G_loss: 2.4481
# Epoch [16/20] Batch [150/782] D_loss: 0.5521 | G_loss: 2.7785
# Epoch [16/20] Batch [200/782] D_loss: 0.4925 | G_loss: 2.6822
# Epoch [16/20] Batch [250/782] D_loss: 0.7982 | G_loss: 3.4897
# Epoch [16/20] Batch [300/782] D_loss: 0.5918 | G_loss: 2.5094
# Epoch [16/20] Batch [350/782] D_loss: 0.6608 | G_loss: 1.9728
# Epoch [16/20] Batch [400/782] D_loss: 0.6310 | G_loss: 2.9026
# Epoch [16/20] Batch [450/782] D_loss: 0.9722 | G_loss: 1.8426
# Epoch [16/20] Batch [500/782] D_loss: 0.6812 | G_loss: 2.6345
# Epoch [16/20] Batch [550/782] D_loss: 0.8687 | G_loss: 2.7000
# Epoch [16/20] Batch [600/782] D_loss: 0.8415 | G_loss: 2.3868
# Epoch [16/20] Batch [650/782] D_loss: 0.8499 | G_loss: 3.3127
# Epoch [16/20] Batch [700/782] D_loss: 1.2730 | G_loss: 1.6058
# Epoch [16/20] Batch [750/782] D_loss: 1.0007 | G_loss: 3.4021
# Epoch [17/20] Batch [50/782] D_loss: 0.7063 | G_loss: 2.2449
# Epoch [17/20] Batch [100/782] D_loss: 0.5502 | G_loss: 2.7953
# Epoch [17/20] Batch [150/782] D_loss: 0.9686 | G_loss: 1.9819
# Epoch [17/20] Batch [200/782] D_loss: 0.3577 | G_loss: 2.7242
# Epoch [17/20] Batch [250/782] D_loss: 0.4591 | G_loss: 2.6386
# Epoch [17/20] Batch [300/782] D_loss: 0.4213 | G_loss: 2.7608
# Epoch [17/20] Batch [350/782] D_loss: 0.5894 | G_loss: 2.5014
# Epoch [17/20] Batch [400/782] D_loss: 0.4086 | G_loss: 3.9123
# Epoch [17/20] Batch [450/782] D_loss: 0.5199 | G_loss: 3.9115
# Epoch [17/20] Batch [500/782] D_loss: 0.4287 | G_loss: 3.2704
# Epoch [17/20] Batch [550/782] D_loss: 0.6361 | G_loss: 2.1556
# Epoch [17/20] Batch [600/782] D_loss: 0.7649 | G_loss: 2.8627
# Epoch [17/20] Batch [650/782] D_loss: 0.4097 | G_loss: 2.7044
# Epoch [17/20] Batch [700/782] D_loss: 0.9053 | G_loss: 3.3130
# Epoch [17/20] Batch [750/782] D_loss: 0.4734 | G_loss: 3.1106
# Epoch [18/20] Batch [50/782] D_loss: 0.8841 | G_loss: 2.8862
# Epoch [18/20] Batch [100/782] D_loss: 0.5784 | G_loss: 2.7307
# Epoch [18/20] Batch [150/782] D_loss: 0.5913 | G_loss: 3.7369
# Epoch [18/20] Batch [200/782] D_loss: 0.6287 | G_loss: 2.2736
# Epoch [18/20] Batch [250/782] D_loss: 0.4738 | G_loss: 2.6949
# Epoch [18/20] Batch [300/782] D_loss: 0.3920 | G_loss: 2.4617
# Epoch [18/20] Batch [350/782] D_loss: 0.5561 | G_loss: 2.9716
# Epoch [18/20] Batch [400/782] D_loss: 1.0024 | G_loss: 3.2950
# Epoch [18/20] Batch [450/782] D_loss: 0.6899 | G_loss: 2.1953
# Epoch [18/20] Batch [500/782] D_loss: 0.5509 | G_loss: 3.3030
# Epoch [18/20] Batch [550/782] D_loss: 0.7276 | G_loss: 3.0985
# Epoch [18/20] Batch [600/782] D_loss: 0.5593 | G_loss: 2.7036
# Epoch [18/20] Batch [650/782] D_loss: 0.6405 | G_loss: 2.4527
# Epoch [18/20] Batch [700/782] D_loss: 0.5333 | G_loss: 3.0439
# Epoch [18/20] Batch [750/782] D_loss: 0.5968 | G_loss: 2.4334
# Epoch [19/20] Batch [50/782] D_loss: 0.3121 | G_loss: 2.6384
# Epoch [19/20] Batch [100/782] D_loss: 0.7283 | G_loss: 2.7593
# Epoch [19/20] Batch [150/782] D_loss: 0.6957 | G_loss: 1.8635
# Epoch [19/20] Batch [200/782] D_loss: 0.4979 | G_loss: 2.3395
# Epoch [19/20] Batch [250/782] D_loss: 0.5441 | G_loss: 2.9891
# Epoch [19/20] Batch [300/782] D_loss: 0.5305 | G_loss: 2.2838
# Epoch [19/20] Batch [350/782] D_loss: 0.4556 | G_loss: 3.0073
# Epoch [19/20] Batch [400/782] D_loss: 0.6059 | G_loss: 2.3235
# Epoch [19/20] Batch [450/782] D_loss: 0.4230 | G_loss: 2.3523
# Epoch [19/20] Batch [500/782] D_loss: 0.5735 | G_loss: 2.6170
# Epoch [19/20] Batch [550/782] D_loss: 1.0615 | G_loss: 4.1389
# Epoch [19/20] Batch [600/782] D_loss: 0.6120 | G_loss: 2.3486
# Epoch [19/20] Batch [650/782] D_loss: 0.4600 | G_loss: 3.0438
# Epoch [19/20] Batch [700/782] D_loss: 0.4115 | G_loss: 2.9525
# Epoch [19/20] Batch [750/782] D_loss: 0.5208 | G_loss: 2.7481
# Epoch [20/20] Batch [50/782] D_loss: 0.6110 | G_loss: 3.4772
# Epoch [20/20] Batch [100/782] D_loss: 0.5408 | G_loss: 2.6916
# Epoch [20/20] Batch [150/782] D_loss: 0.8325 | G_loss: 2.5102
# Epoch [20/20] Batch [200/782] D_loss: 0.7348 | G_loss: 3.0114
# Epoch [20/20] Batch [250/782] D_loss: 0.8019 | G_loss: 3.2933
# Epoch [20/20] Batch [300/782] D_loss: 0.8510 | G_loss: 2.7883
# Epoch [20/20] Batch [350/782] D_loss: 1.0648 | G_loss: 2.6685
# Epoch [20/20] Batch [400/782] D_loss: 0.9379 | G_loss: 3.1577
# Epoch [20/20] Batch [450/782] D_loss: 0.5294 | G_loss: 2.1172
# Epoch [20/20] Batch [500/782] D_loss: 0.6811 | G_loss: 2.9554
# Epoch [20/20] Batch [550/782] D_loss: 0.5579 | G_loss: 2.2867
# Epoch [20/20] Batch [600/782] D_loss: 0.4828 | G_loss: 3.5548
# Epoch [20/20] Batch [650/782] D_loss: 0.5139 | G_loss: 3.3110
# Epoch [20/20] Batch [700/782] D_loss: 0.3363 | G_loss: 3.1270
# Epoch [20/20] Batch [750/782] D_loss: 0.8076 | G_loss: 2.7339
#
#  Epoch 20 Complete - Avg D_loss: 0.6859 | Avg G_loss: 2.7975
#
#
# ================================================================================
# Training Complete!
# ================================================================================
#
# ✓ Training complete after 20 epochs

# %% [markdown]
# ## Solution 5: Plot Training Loss Curves

# %%
print("=" * 80)
print("SOLUTION 5: Plotting Loss Curves")
print("=" * 80)

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Discriminator loss
ax = axes[0]
ax.plot(results["d_losses"], linewidth=1, color="navy", alpha=0.7, label="D Loss")
ax.axhline(y=0.5, color="gray", linestyle="--", alpha=0.5, label="Ideal (0.5)")
ax.set_xlabel("Training Step", fontsize=11)
ax.set_ylabel("BCE Loss", fontsize=11)
ax.set_title("Discriminator Loss Over Training\n(cGAN)", fontsize=12, fontweight="bold")
ax.grid(alpha=0.3)
ax.legend(fontsize=10)
ax.set_ylim([0, max(results["d_losses"][:100]) * 1.2])

# Generator loss
ax = axes[1]
ax.plot(results["g_losses"], linewidth=1, color="darkgreen", alpha=0.7, label="G Loss")
ax.set_xlabel("Training Step", fontsize=11)
ax.set_ylabel("BCE Loss", fontsize=11)
ax.set_title("Generator Loss Over Training\n(cGAN)", fontsize=12, fontweight="bold")
ax.grid(alpha=0.3)
ax.legend(fontsize=10)
ax.set_ylim([0, max(results["g_losses"][:100]) * 1.2])

plt.tight_layout()
plt.show()

# Print statistics
d_losses = np.array(results["d_losses"])
g_losses = np.array(results["g_losses"])
print(f"Discriminator Loss - Mean: {d_losses.mean():.4f}, Std: {d_losses.std():.4f}")
print(f"Generator Loss - Mean: {g_losses.mean():.4f}, Std: {g_losses.std():.4f}\n")
# Out:
# ================================================================================
# SOLUTION 5: Plotting Loss Curves
# ================================================================================
# Discriminator Loss - Mean: 0.8796, Std: 0.2463
# Generator Loss - Mean: 2.1522, Std: 0.5977

# %% [markdown]
# ## Solution 6: Class Disentanglement Grid (10×10)

# %%
print("=" * 80)
print("SOLUTION 6: Generating 10×10 Class Disentanglement Grid")
print("=" * 80)

#ToDo
grid_images = trainer.generate_all_classes_grid(
    num_classes=10,
    samples_per_class=10,
    latent_dim=latent_dim,
    shared_z=None,
)

# Denormalize to [0, 1]
grid_images_cpu = (grid_images.cpu() + 1) / 2
grid_images_cpu = torch.clamp(grid_images_cpu, 0, 1)

# Visualize as 10×10 grid
fig, axes = plt.subplots(10, 10, figsize=(16, 16))
for class_id in range(10):
    for sample_id in range(10):
        idx = class_id * 10 + sample_id
        ax = axes[class_id, sample_id]
        img = grid_images_cpu[idx].permute(1, 2, 0).numpy()
        ax.imshow(img)
        ax.axis("off")
        if sample_id == 0:
            ax.set_ylabel(CIFAR10_CLASSES[class_id], fontsize=10, fontweight="bold")

plt.suptitle(
    "cGAN Class Disentanglement: 10×10 Grid\n(Rows: Classes | Columns: Same Noise, Different Classes)",
    fontsize=14,
    fontweight="bold",
    y=0.995,
)
plt.tight_layout()
plt.show()

print(f" Generated class grid: {grid_images.shape}")
print(f"  - 10 classes × 10 samples per class = 100 total images")
print(f"  - Same noise z, different class labels y\n")
# Out:
# ================================================================================
# SOLUTION 6: Generating 10×10 Class Disentanglement Grid
# ================================================================================
#  Generated class grid: torch.Size([100, 3, 33, 33])
#   - 10 classes × 10 samples per class = 100 total images
#   - Same noise z, different class labels y

# %% [markdown]
# ## Solution 7: Generate Single-Class Samples

# %%
print("=" * 80)
print("SOLUTION 7: Generating Single-Class Samples")
print("=" * 80)

target_class = 5  # dogs
class_samples = trainer.generate_class_samples(
    target_class=target_class,
    num_samples=16,
    latent_dim=latent_dim,
)

# Denormalize
class_samples_cpu = (class_samples.cpu() + 1) / 2
class_samples_cpu = torch.clamp(class_samples_cpu, 0, 1)

# Visualize
fig, axes = plt.subplots(2, 8, figsize=(16, 4))
for i in range(16):
    ax = axes[i // 8, i % 8]
    img = class_samples_cpu[i].permute(1, 2, 0).numpy()
    ax.imshow(img)
    ax.axis("off")

plt.suptitle(
    f'16 Generated Samples from Class "{CIFAR10_CLASSES[target_class]}"',
    fontsize=12,
    fontweight="bold",
)
plt.tight_layout()
plt.show()

print(
    f" Generated 16 samples from class {CIFAR10_CLASSES[target_class]} (class {target_class})"
)
print(f"  - Each image generated with different noise z")
print(f"  - All images conditioned on same class label y={target_class}\n")
# Out:
# ================================================================================
# SOLUTION 7: Generating Single-Class Samples
# ================================================================================
#  Generated 16 samples from class dog (class 5)
#   - Each image generated with different noise z
#   - All images conditioned on same class label y=5
