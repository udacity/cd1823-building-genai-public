# %% [markdown]
# ## Import Required Libraries

# %%
# Make the shared `models` package (at the project root) importable from this
# lesson folder. Without this, `from models... import ...` raises ModuleNotFoundError.
import sys, pathlib
_root = next((p for p in [pathlib.Path.cwd(), *pathlib.Path.cwd().parents]
              if (p / "models").is_dir()), None)
if _root and str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from models.dcgan import (
    DCGANDiscriminator,
    DCGANGenerator,
    create_dcgan_models,
    print_model_summary,
)
from models.dcgan_training import DCGANTrainer, initialize_weights
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %% [markdown]
# ## SECTION 1: Device Setup

# %%
print("\n" + "=" * 80)
print("DCGAN EXERCISE - COMPLETE SOLUTION")
print("=" * 80 + "\n")

print(" SECTION 1: Setting up device and reproducibility...")

if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(f"✓ Device: {device}")

# Set seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
# Out:
# ================================================================================
# DCGAN EXERCISE - COMPLETE SOLUTION
# ================================================================================
#
#  SECTION 1: Setting up device and reproducibility...
# ✓ Device: cuda

# %%
# Visualization helpers (provided - focus on the model!)
def plot_loss_curves(d_losses, g_losses):
    """Plot discriminator and generator losses."""
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    axes[0].plot(d_losses, linewidth=2, color="navy", label="D Loss")
    axes[0].axhline(y=0.5, color="red", linestyle="--", alpha=0.5, label="Ideal (0.5)")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Loss")
    axes[0].set_title("Discriminator Loss")
    axes[0].legend()
    axes[0].grid(alpha=0.3)

    axes[1].plot(g_losses, linewidth=2, color="darkgreen", label="G Loss")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Loss")
    axes[1].set_title("Generator Loss")
    axes[1].legend()
    axes[1].grid(alpha=0.3)

    plt.tight_layout()
    plt.show()


def visualize_generated_images(generator, num_samples=16, device="cpu"):
    """Generate and display images."""
    generator.eval()

    with torch.no_grad():
        z = torch.randn(num_samples, 100, device=device)
        images = generator(z)

    # Denormalize
    images = (images + 1) / 2
    images = torch.clamp(images, 0, 1)

    # Display
    fig, axes = plt.subplots(4, 4, figsize=(8, 8))
    for i, ax in enumerate(axes.flat):
        img = images[i].cpu().permute(1, 2, 0).numpy()
        ax.imshow(img)
        ax.axis("off")

    plt.suptitle("Generated Images", fontsize=14, fontweight="bold")
    plt.tight_layout()
    plt.show()


print("Visualization helpers loaded")
# Out:
# Visualization helpers loaded

# %% [markdown]
# ## ToDo 1: Load CIFAR-10 Dataset

# %%
print("\n SECTION 2: Loading CIFAR-10 dataset...")

#ToDo: Define Transforms
transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ]
)

#ToDo 2: Load CIFAR-10 Dataset
train_dataset = datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=transform,
)

batch_size = 64

#ToDo: Create DataLoader
train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,
)

print(f"✓ Loaded {len(train_dataset)} training images")
print(f"✓ Batch size: {batch_size}")
print(f"✓ Batches per epoch: {len(train_loader)}")
print(f"✓ Image shape: (3, 32, 32)")
# Out:
#  SECTION 2: Loading CIFAR-10 dataset...
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:01<00:00, 94.2MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# ✓ Loaded 50000 training images
# ✓ Batch size: 64
# ✓ Batches per epoch: 782
# ✓ Image shape: (3, 32, 32)

# %% [markdown]
# ### TODO 2: Build Generator Network

# %%
# TODO 2: Implement Generator
class Generator(nn.Module):
    def __init__(self, latent_dim=100, num_channels=3):
        super().__init__()

        # TODO: FC layer from latent_dim to 256*8*8
        self.fc = nn.Linear(latent_dim, 256 * 8 * 8)

        # TODO: ConvTranspose blocks
        # - 256x8x8 -> 128x16x16 (with BatchNorm + ReLU)
        # - 128x16x16 -> 64x32x32 (with BatchNorm + ReLU)
        # - 64x32x32 -> 3x32x32 (with Tanh, no BatchNorm)
        self.main = nn.Sequential(
            # 256x8x8 -> 128x16x16
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            # 128x16x16 -> 64x32x32
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            # 64x32x32 -> 3x32x32 (with Tanh, no BatchNorm)
            nn.ConvTranspose2d(64, num_channels, kernel_size=3, stride=1, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        # z: (batch, latent_dim)
        # TODO: FC -> reshape to (batch, 256, 8, 8) -> main -> output
        x = self.fc(z)  # (batch, 256*8*8)
        x = x.view(x.size(0), 256, 8, 8)  # (batch, 256, 8, 8)
        x = self.main(x)  # (batch, 3, 32, 32)
        return x


generator = Generator(latent_dim=100, num_channels=3).to(device)
print(
    f"Generator created. Parameters: {sum(p.numel() for p in generator.parameters()):,}"
)
# Out:
# Generator created. Parameters: 2,312,451

# %% [markdown]
# ## TODO 3: Build Discriminator Network
#
# **Architecture:**
# - Input: Image (batch, 3, 32, 32)
# - Conv block 1: 32×32 → 16×16 (3 → 64 channels)
# - Conv block 2: 16×16 → 8×8 (64 → 128 channels)
# - Conv block 3: 8×8 → 4×4 (128 → 256 channels)
# - Flatten to (256 * 4 * 4) = 4,096 features
# - FC: 4096 → 1024 → 1 with Sigmoid output
#
# **Use:** `nn.Conv2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1)`

# %%
# TODO 3: Implement Discriminator
class Discriminator(nn.Module):
    def __init__(self, num_channels=3):
        super().__init__()

        # TODO: Conv blocks (no BatchNorm on first, then BatchNorm + LeakyReLU)
        # - 3x32x32 -> 64x16x16 (LeakyReLU only)
        # - 64x16x16 -> 128x8x8 (BatchNorm + LeakyReLU)
        # - 128x8x8 -> 256x4x4 (BatchNorm + LeakyReLU)
        self.main = nn.Sequential(
            # 3x32x32 -> 64x16x16 (LeakyReLU only, no BatchNorm)
            nn.Conv2d(num_channels, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            
            # 64x16x16 -> 128x8x8 (BatchNorm + LeakyReLU)
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            
            # 128x8x8 -> 256x4x4 (BatchNorm + LeakyReLU)
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
        )

        # TODO: FC layers to output
        # - Flatten -> 4096 -> 1024 -> 1 (with Sigmoid)
        self.fc = nn.Sequential(
            nn.Linear(256 * 4 * 4, 1024),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1024, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        # x: (batch, 3, 32, 32)
        # TODO: Conv blocks -> flatten -> fc -> output
        x = self.main(x)  # (batch, 256, 4, 4)
        x = x.view(x.size(0), -1)  # Flatten to (batch, 256*4*4)
        x = self.fc(x)  # (batch, 1)
        return x


discriminator = Discriminator(num_channels=3).to(device)
print(
    f"Discriminator created. Parameters: {sum(p.numel() for p in discriminator.parameters()):,}"
)
# Out:
# Discriminator created. Parameters: 4,856,001

# %% [markdown]
# ## TODO 4: Weight Initialization
#
# **DCGAN standard:**
# - Conv/ConvTranspose: `Normal(mean=0, std=0.02)`
# - BatchNorm: `Normal(mean=1, std=0.02)` weight, bias=0
#
# **Use:**
# - `nn.init.normal_(m.weight, 0.0, 0.02)`
# - `nn.init.normal_(m.weight, 1.0, 0.02)` for BatchNorm

# %%
# TODO 4: Implement weight initialization
def initialize_weights(model):
    # TODO: Iterate through model.modules()
    # - For Conv2d/ConvTranspose2d: nn.init.normal_(m.weight, 0.0, 0.02)
    # - For BatchNorm2d: nn.init.normal_(m.weight, 1.0, 0.02), nn.init.constant_(m.bias, 0.0)
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
            # Initialize weights from normal distribution (mean=0.0, std=0.02)
            nn.init.normal_(m.weight, 0.0, 0.02)
        elif isinstance(m, nn.BatchNorm2d):
            # Initialize weights from normal distribution (mean=1.0, std=0.02)
            nn.init.normal_(m.weight, 1.0, 0.02)
            # Initialize biases to 0
            nn.init.constant_(m.bias, 0.0)


initialize_weights(generator)
initialize_weights(discriminator)
print(" Weights initialized")
# Out:
#  Weights initialized

# %% [markdown]
# ## TODO 5: Set Up Optimizers and Loss
#
# **Configuration:**
# - Adam optimizer with lr=0.0002, beta1=0.5, beta2=0.999
# - BCELoss for real/fake classification
#
# **Note:** beta1=0.5 is unusual but empirically works better for GANs than default 0.9

# %%
# TODO 5: Set up optimizers and loss
lr = 0.0002
beta1 = 0.5

# TODO: Create Adam optimizers for G and D
optimizer_g = torch.optim.Adam(
    generator.parameters(), 
    lr=lr, 
    betas=(beta1, 0.999)
)
optimizer_d = torch.optim.Adam(
    discriminator.parameters(), 
    lr=lr, 
    betas=(beta1, 0.999)
)

# TODO: Create BCELoss criterion
criterion = nn.BCELoss()

print(" Optimizers and loss initialized")
# Out:
#  Optimizers and loss initialized

# %% [markdown]
# ## TODO 6: Implement Training Loop
#
# **Discriminator step:**
# 1. Forward real images → target=1
# 2. Generate fake images (detached)
# 3. Forward fake images → target=0
# 4. Sum losses and backprop
#
# **Generator step:**
# 1. Generate fake| images (NOT detached)
# 2. Forward through discriminator
# 3. Try to fool D → target=1
# 4. Backprop generator only

# %%
# TODO 6: Training loop
num_epochs = 20
d_losses = []
g_losses = []

for epoch in range(num_epochs):
    epoch_d_loss = 0.0
    epoch_g_loss = 0.0

    for batch_idx, (real_images, _) in enumerate(train_loader):
        real_images = real_images.to(device)
        batch_size = real_images.size(0)

        # TODO: Discriminator step
        # 1. optimizer_d.zero_grad()
        # 2. Forward real images, compute loss with target=1
        # 3. Generate fake images with torch.randn(batch_size, 100, device=device)
        # 4. Forward fake images (detached!), compute loss with target=0
        # 5. d_loss = real_loss + fake_loss
        # 6. d_loss.backward() and optimizer_d.step()
        optimizer_d.zero_grad()
        
        # Real images forward pass
        real_output = discriminator(real_images)
        real_labels = torch.ones(batch_size, 1, device=device)
        real_loss = criterion(real_output, real_labels)
        
        # Fake images forward pass
        z = torch.randn(batch_size, 100, device=device)
        fake_images = generator(z).detach()  # Detach to not update generator
        fake_output = discriminator(fake_images)
        fake_labels = torch.zeros(batch_size, 1, device=device)
        fake_loss = criterion(fake_output, fake_labels)
        
        # Total discriminator loss
        d_loss = real_loss + fake_loss
        d_loss.backward()
        optimizer_d.step()

        # TODO: Generator step
        # 1. optimizer_g.zero_grad()
        # 2. Generate new fake images (no detach)
        # 3. Forward through discriminator
        # 4. Compute loss with target=1 (fool D)
        # 5. g_loss.backward() and optimizer_g.step()
        optimizer_g.zero_grad()
        
        # Generate new fake images (NOT detached)
        z = torch.randn(batch_size, 100, device=device)
        fake_images = generator(z)
        
        # Forward through discriminator
        fake_output = discriminator(fake_images)
        
        # Try to fool discriminator (target=1)
        real_labels = torch.ones(batch_size, 1, device=device)
        g_loss = criterion(fake_output, real_labels)
        
        g_loss.backward()
        optimizer_g.step()

        # Track losses
        epoch_d_loss += d_loss.item()
        epoch_g_loss += g_loss.item()

        if (batch_idx + 1) % 100 == 0:
            print(
                f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx+1}/{len(train_loader)}, "
                f"D_Loss: {d_loss.item():.4f}, G_Loss: {g_loss.item():.4f}"
            )

    # Average losses for the epoch
    avg_d_loss = epoch_d_loss / len(train_loader)
    avg_g_loss = epoch_g_loss / len(train_loader)
    d_losses.append(avg_d_loss)
    g_losses.append(avg_g_loss)
    
    print(f"Epoch {epoch+1}/{num_epochs} complete - D_Loss: {avg_d_loss:.4f}, G_Loss: {avg_g_loss:.4f}")

print("✓ Training complete")
# Out:
# Epoch 1/20, Batch 100/782, D_Loss: 0.9398, G_Loss: 3.0862
# Epoch 1/20, Batch 200/782, D_Loss: 0.7338, G_Loss: 2.5555
# Epoch 1/20, Batch 300/782, D_Loss: 1.3233, G_Loss: 1.0109
# Epoch 1/20, Batch 400/782, D_Loss: 1.3840, G_Loss: 1.8196
# Epoch 1/20, Batch 500/782, D_Loss: 1.0140, G_Loss: 1.4371
# Epoch 1/20, Batch 600/782, D_Loss: 0.7636, G_Loss: 1.7740
# Epoch 1/20, Batch 700/782, D_Loss: 1.2006, G_Loss: 1.7059
# Epoch 1/20 complete - D_Loss: 1.0200, G_Loss: 1.8884
# Epoch 2/20, Batch 100/782, D_Loss: 1.1781, G_Loss: 2.1517
# Epoch 2/20, Batch 200/782, D_Loss: 0.8984, G_Loss: 1.2752
# Epoch 2/20, Batch 300/782, D_Loss: 0.9363, G_Loss: 1.8565
# Epoch 2/20, Batch 400/782, D_Loss: 0.6929, G_Loss: 2.0279
# Epoch 2/20, Batch 500/782, D_Loss: 0.7859, G_Loss: 1.6938
# Epoch 2/20, Batch 600/782, D_Loss: 1.0887, G_Loss: 2.4587
# Epoch 2/20, Batch 700/782, D_Loss: 1.0197, G_Loss: 1.5630
# Epoch 2/20 complete - D_Loss: 1.0428, G_Loss: 1.5564
# Epoch 3/20, Batch 100/782, D_Loss: 1.0438, G_Loss: 0.9550
# Epoch 3/20, Batch 200/782, D_Loss: 1.0040, G_Loss: 0.7486
# Epoch 3/20, Batch 300/782, D_Loss: 1.1175, G_Loss: 2.1525
# Epoch 3/20, Batch 400/782, D_Loss: 1.0068, G_Loss: 1.1460
# Epoch 3/20, Batch 500/782, D_Loss: 0.7083, G_Loss: 2.1190
# Epoch 3/20, Batch 600/782, D_Loss: 1.0896, G_Loss: 1.1829
# Epoch 3/20, Batch 700/782, D_Loss: 1.0790, G_Loss: 1.4208
# Epoch 3/20 complete - D_Loss: 1.0043, G_Loss: 1.6355
# Epoch 4/20, Batch 100/782, D_Loss: 0.9775, G_Loss: 0.8829
# Epoch 4/20, Batch 200/782, D_Loss: 1.0777, G_Loss: 1.3149
# Epoch 4/20, Batch 300/782, D_Loss: 1.2427, G_Loss: 0.9257
# Epoch 4/20, Batch 400/782, D_Loss: 1.1251, G_Loss: 0.8509
# Epoch 4/20, Batch 500/782, D_Loss: 1.0056, G_Loss: 1.2609
# Epoch 4/20, Batch 600/782, D_Loss: 1.0146, G_Loss: 1.2130
# Epoch 4/20, Batch 700/782, D_Loss: 1.2720, G_Loss: 1.2653
# Epoch 4/20 complete - D_Loss: 1.0679, G_Loss: 1.4616
# Epoch 5/20, Batch 100/782, D_Loss: 1.2339, G_Loss: 1.5853
# Epoch 5/20, Batch 200/782, D_Loss: 1.3016, G_Loss: 1.4125
# Epoch 5/20, Batch 300/782, D_Loss: 0.9311, G_Loss: 1.3876
# Epoch 5/20, Batch 400/782, D_Loss: 0.7322, G_Loss: 1.8336
# Epoch 5/20, Batch 500/782, D_Loss: 1.1125, G_Loss: 1.0733
# Epoch 5/20, Batch 600/782, D_Loss: 0.7654, G_Loss: 1.4634
# Epoch 5/20, Batch 700/782, D_Loss: 0.9189, G_Loss: 0.9747
# Epoch 5/20 complete - D_Loss: 0.9989, G_Loss: 1.6128
# Epoch 6/20, Batch 100/782, D_Loss: 0.8841, G_Loss: 2.1772
# Epoch 6/20, Batch 200/782, D_Loss: 1.5417, G_Loss: 0.6632
# Epoch 6/20, Batch 300/782, D_Loss: 0.6798, G_Loss: 1.8719
# Epoch 6/20, Batch 400/782, D_Loss: 0.7678, G_Loss: 2.2157
# Epoch 6/20, Batch 500/782, D_Loss: 0.7869, G_Loss: 1.8139
# Epoch 6/20, Batch 600/782, D_Loss: 0.7664, G_Loss: 2.3210
# Epoch 6/20, Batch 700/782, D_Loss: 0.7696, G_Loss: 2.1861
# Epoch 6/20 complete - D_Loss: 0.9318, G_Loss: 1.7837
# Epoch 7/20, Batch 100/782, D_Loss: 0.7908, G_Loss: 1.1425
# Epoch 7/20, Batch 200/782, D_Loss: 0.8946, G_Loss: 1.2097
# Epoch 7/20, Batch 300/782, D_Loss: 0.9751, G_Loss: 0.7728
# Epoch 7/20, Batch 400/782, D_Loss: 1.3387, G_Loss: 0.5188
# Epoch 7/20, Batch 500/782, D_Loss: 1.2927, G_Loss: 3.1063
# Epoch 7/20, Batch 600/782, D_Loss: 1.0185, G_Loss: 1.7479
# Epoch 7/20, Batch 700/782, D_Loss: 0.7089, G_Loss: 2.2423
# Epoch 7/20 complete - D_Loss: 0.9339, G_Loss: 1.7814
# Epoch 8/20, Batch 100/782, D_Loss: 0.8312, G_Loss: 1.5356
# Epoch 8/20, Batch 200/782, D_Loss: 1.1665, G_Loss: 3.8073
# Epoch 8/20, Batch 300/782, D_Loss: 1.4893, G_Loss: 2.4320
# Epoch 8/20, Batch 400/782, D_Loss: 0.7267, G_Loss: 2.4385
# Epoch 8/20, Batch 500/782, D_Loss: 0.8341, G_Loss: 1.4438
# Epoch 8/20, Batch 600/782, D_Loss: 0.8626, G_Loss: 1.2305
# Epoch 8/20, Batch 700/782, D_Loss: 1.3913, G_Loss: 0.8437
# Epoch 8/20 complete - D_Loss: 0.9505, G_Loss: 1.7128
# Epoch 9/20, Batch 100/782, D_Loss: 0.9003, G_Loss: 2.3975
# Epoch 9/20, Batch 200/782, D_Loss: 0.8942, G_Loss: 1.8001
# Epoch 9/20, Batch 300/782, D_Loss: 0.8140, G_Loss: 1.2348
# Epoch 9/20, Batch 400/782, D_Loss: 0.9598, G_Loss: 0.9650
# Epoch 9/20, Batch 500/782, D_Loss: 0.8437, G_Loss: 1.2058
# Epoch 9/20, Batch 600/782, D_Loss: 0.8528, G_Loss: 1.5293
# Epoch 9/20, Batch 700/782, D_Loss: 0.6192, G_Loss: 1.6148
# Epoch 9/20 complete - D_Loss: 0.9384, G_Loss: 1.7112
# Epoch 10/20, Batch 100/782, D_Loss: 0.7200, G_Loss: 2.2219
# Epoch 10/20, Batch 200/782, D_Loss: 1.0355, G_Loss: 0.6803
# Epoch 10/20, Batch 300/782, D_Loss: 1.4637, G_Loss: 3.6882
# Epoch 10/20, Batch 400/782, D_Loss: 0.6105, G_Loss: 1.3758
# Epoch 10/20, Batch 500/782, D_Loss: 1.2028, G_Loss: 1.3992
# Epoch 10/20, Batch 600/782, D_Loss: 0.9311, G_Loss: 2.4695
# Epoch 10/20, Batch 700/782, D_Loss: 0.7407, G_Loss: 2.3906
# Epoch 10/20 complete - D_Loss: 0.9304, G_Loss: 1.7424
# Epoch 11/20, Batch 100/782, D_Loss: 0.7521, G_Loss: 1.0550
# Epoch 11/20, Batch 200/782, D_Loss: 0.7971, G_Loss: 2.3707
# Epoch 11/20, Batch 300/782, D_Loss: 0.6691, G_Loss: 1.4002
# Epoch 11/20, Batch 400/782, D_Loss: 0.8589, G_Loss: 1.3010
# Epoch 11/20, Batch 500/782, D_Loss: 0.6164, G_Loss: 1.8666
# Epoch 11/20, Batch 600/782, D_Loss: 0.9062, G_Loss: 1.2147
# Epoch 11/20, Batch 700/782, D_Loss: 0.8440, G_Loss: 1.1173
# Epoch 11/20 complete - D_Loss: 0.8944, G_Loss: 1.8317
# Epoch 12/20, Batch 100/782, D_Loss: 1.0216, G_Loss: 0.5029
# Epoch 12/20, Batch 200/782, D_Loss: 0.8906, G_Loss: 1.9578
# Epoch 12/20, Batch 300/782, D_Loss: 0.6709, G_Loss: 2.1545
# Epoch 12/20, Batch 400/782, D_Loss: 0.8536, G_Loss: 1.6720
# Epoch 12/20, Batch 500/782, D_Loss: 0.6069, G_Loss: 2.8633
# Epoch 12/20, Batch 600/782, D_Loss: 0.6763, G_Loss: 1.9671
# Epoch 12/20, Batch 700/782, D_Loss: 0.8486, G_Loss: 1.3703
# Epoch 12/20 complete - D_Loss: 0.8718, G_Loss: 1.9079
# Epoch 13/20, Batch 100/782, D_Loss: 0.9007, G_Loss: 1.1236
# Epoch 13/20, Batch 200/782, D_Loss: 1.4340, G_Loss: 2.5588
# Epoch 13/20, Batch 300/782, D_Loss: 0.6897, G_Loss: 1.9659
# Epoch 13/20, Batch 400/782, D_Loss: 0.8051, G_Loss: 1.9321
# Epoch 13/20, Batch 500/782, D_Loss: 0.8085, G_Loss: 1.7431
# Epoch 13/20, Batch 600/782, D_Loss: 0.4614, G_Loss: 1.8433
# Epoch 13/20, Batch 700/782, D_Loss: 1.1189, G_Loss: 1.6588
# Epoch 13/20 complete - D_Loss: 0.8351, G_Loss: 2.0006
# Epoch 14/20, Batch 100/782, D_Loss: 1.2227, G_Loss: 3.4197
# Epoch 14/20, Batch 200/782, D_Loss: 0.9173, G_Loss: 1.8828
# Epoch 14/20, Batch 300/782, D_Loss: 0.8458, G_Loss: 1.4570
# Epoch 14/20, Batch 400/782, D_Loss: 0.5774, G_Loss: 1.5400
# Epoch 14/20, Batch 500/782, D_Loss: 0.6334, G_Loss: 2.3894
# Epoch 14/20, Batch 600/782, D_Loss: 0.6725, G_Loss: 1.5591
# Epoch 14/20, Batch 700/782, D_Loss: 1.0191, G_Loss: 1.4677
# Epoch 14/20 complete - D_Loss: 0.8146, G_Loss: 2.0922
# Epoch 15/20, Batch 100/782, D_Loss: 0.5587, G_Loss: 1.9358
# Epoch 15/20, Batch 200/782, D_Loss: 0.6343, G_Loss: 2.4936
# Epoch 15/20, Batch 300/782, D_Loss: 0.9800, G_Loss: 1.5579
# Epoch 15/20, Batch 400/782, D_Loss: 0.8838, G_Loss: 1.9994
# Epoch 15/20, Batch 500/782, D_Loss: 1.0683, G_Loss: 1.0569
# Epoch 15/20, Batch 600/782, D_Loss: 0.7102, G_Loss: 2.6118
# Epoch 15/20, Batch 700/782, D_Loss: 0.6320, G_Loss: 1.8578
# Epoch 15/20 complete - D_Loss: 0.7893, G_Loss: 2.1765
# Epoch 16/20, Batch 100/782, D_Loss: 0.6748, G_Loss: 2.2704
# Epoch 16/20, Batch 200/782, D_Loss: 0.9019, G_Loss: 3.7309
# Epoch 16/20, Batch 300/782, D_Loss: 0.8450, G_Loss: 1.6921
# Epoch 16/20, Batch 400/782, D_Loss: 0.5891, G_Loss: 2.4636
# Epoch 16/20, Batch 500/782, D_Loss: 0.5052, G_Loss: 2.3029
# Epoch 16/20, Batch 600/782, D_Loss: 0.6827, G_Loss: 2.5651
# Epoch 16/20, Batch 700/782, D_Loss: 0.8271, G_Loss: 2.7618
# Epoch 16/20 complete - D_Loss: 0.7632, G_Loss: 2.2195
# Epoch 17/20, Batch 100/782, D_Loss: 0.4509, G_Loss: 2.5387
# Epoch 17/20, Batch 200/782, D_Loss: 0.6325, G_Loss: 2.2014
# Epoch 17/20, Batch 300/782, D_Loss: 0.6282, G_Loss: 2.7137
# Epoch 17/20, Batch 400/782, D_Loss: 0.9116, G_Loss: 3.8345
# Epoch 17/20, Batch 500/782, D_Loss: 0.7839, G_Loss: 3.1249
# Epoch 17/20, Batch 600/782, D_Loss: 0.6158, G_Loss: 1.2866
# Epoch 17/20, Batch 700/782, D_Loss: 0.6754, G_Loss: 1.5844
# Epoch 17/20 complete - D_Loss: 0.7460, G_Loss: 2.3017
# Epoch 18/20, Batch 100/782, D_Loss: 0.6604, G_Loss: 2.3267
# Epoch 18/20, Batch 200/782, D_Loss: 0.2983, G_Loss: 2.9582
# Epoch 18/20, Batch 300/782, D_Loss: 0.4388, G_Loss: 2.5794
# Epoch 18/20, Batch 400/782, D_Loss: 0.4334, G_Loss: 1.8698
# Epoch 18/20, Batch 500/782, D_Loss: 0.3939, G_Loss: 3.5149
# Epoch 18/20, Batch 600/782, D_Loss: 0.6281, G_Loss: 2.0384
# Epoch 18/20, Batch 700/782, D_Loss: 0.6403, G_Loss: 1.9516
# Epoch 18/20 complete - D_Loss: 0.7100, G_Loss: 2.4177
# Epoch 19/20, Batch 100/782, D_Loss: 0.7756, G_Loss: 1.0181
# Epoch 19/20, Batch 200/782, D_Loss: 0.4003, G_Loss: 2.3764
# Epoch 19/20, Batch 300/782, D_Loss: 0.8093, G_Loss: 2.0867
# Epoch 19/20, Batch 400/782, D_Loss: 0.6318, G_Loss: 3.1267
# Epoch 19/20, Batch 500/782, D_Loss: 0.7202, G_Loss: 2.0508
# Epoch 19/20, Batch 600/782, D_Loss: 0.4344, G_Loss: 2.2021
# Epoch 19/20, Batch 700/782, D_Loss: 0.6485, G_Loss: 2.0244
# Epoch 19/20 complete - D_Loss: 0.6993, G_Loss: 2.5063
# Epoch 20/20, Batch 100/782, D_Loss: 0.6636, G_Loss: 1.9450
# Epoch 20/20, Batch 200/782, D_Loss: 0.9169, G_Loss: 2.4592
# Epoch 20/20, Batch 300/782, D_Loss: 0.6323, G_Loss: 2.3833
# Epoch 20/20, Batch 400/782, D_Loss: 0.3643, G_Loss: 3.0416
# Epoch 20/20, Batch 500/782, D_Loss: 1.3235, G_Loss: 1.3927
# Epoch 20/20, Batch 600/782, D_Loss: 0.9642, G_Loss: 1.7391
# Epoch 20/20, Batch 700/782, D_Loss: 0.5367, G_Loss: 3.4568
# Epoch 20/20 complete - D_Loss: 0.6773, G_Loss: 2.5710
# ✓ Training complete

# %% [markdown]
# ## TODO 7: Plot Loss Curves
#
# **What to look for:**
# - D loss stabilizes around 0.5
# - G loss generally decreases
# - No divergence or wild oscillations

# %%
# TODO 7: Plot loss curves
plot_loss_curves(d_losses, g_losses)

# %% [markdown]
# ## TODO 8: Generate and Visualize Images
#
# **Steps:**
# 1. Set generator to eval mode
# 2. Generate 16 samples with `torch.no_grad()`
# 3. Denormalize: `(generated + 1) / 2` and clamp to [0, 1]
# 4. Display as 4×4 grid

# %%
# TODO 8: Generate and visualize images
visualize_generated_images(generator, num_samples=16, device=device)
